# %%
import magenta

configuracion_base="basic_rnn"

# %%
input_dir="./partituras_midi"
output_tf_record_file="./melody_rnn/data/notesequences.tf.record"

################################## CREACION DEL TF.RECORD A PARTIR DE LAS PARTITURAS MIDI ############
# !convert_dir_to_note_sequences --input_dir=$input_dir --output_file=$output_tf_record_file --recursive
# Out:
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# INFO:tensorflow:Converting files in './partituras_midi\'.
# I0618 11:01:38.466443 14788 convert_dir_to_note_sequences.py:83] Converting files in './partituras_midi\'.
# INFO:tensorflow:0 files converted.
# I0618 11:01:38.469441 14788 convert_dir_to_note_sequences.py:88] 0 files converted.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_01_mono.mid.
# I0618 11:01:38.526288 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_01_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_02_mono.mid.
# I0618 11:01:38.592108 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_02_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_03_mono.mid.
# I0618 11:01:38.659929 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_03_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_04_mono.mid.
# I0618 11:01:38.760661 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_04_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_05_mono.mid.
# I0618 11:01:38.830477 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_05_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_06_mono.mid.
# I0618 11:01:38.894306 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_06_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_07_mono.mid.
# I0618 11:01:39.092779 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_07_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_08_mono.mid.
# I0618 11:01:39.233407 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_08_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_09_mono.mid.
# I0618 11:01:39.315191 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_09_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_10_mono.mid.
# I0618 11:01:39.398966 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_10_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_11_mono.mid.
# I0618 11:01:39.454819 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_11_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_12_mono.mid.
# I0618 11:01:39.504689 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_12_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_13_mono.mid.
# I0618 11:01:39.546575 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_13_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_14_mono.mid.
# I0618 11:01:39.601439 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_14_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_15_mono.mid.
# I0618 11:01:39.670263 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_15_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_16_mono.mid.
# I0618 11:01:39.763997 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_16_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_18_mono.mid.
# I0618 11:01:39.834812 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_18_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_19_mono.mid.
# I0618 11:01:39.877696 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_19_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_20_mono.mid.
# I0618 11:01:39.915596 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_20_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_21_mono.mid.
# I0618 11:01:39.952497 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_21_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_22_mono.mid.
# I0618 11:01:39.991393 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_22_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_23_mono.mid.
# I0618 11:01:40.046249 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_23_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_24_mono.mid.
# I0618 11:01:40.094120 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_24_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_25_mono.mid.
# I0618 11:01:40.141996 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_25_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_26_mono.mid.
# I0618 11:01:40.193857 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_26_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_27_mono.mid.
# I0618 11:01:40.261676 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_27_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_28_mono.mid.
# I0618 11:01:40.345453 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_28_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_29_mono.mid.
# I0618 11:01:40.396321 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_29_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_30_mono.mid.
# I0618 11:01:40.442197 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_30_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_31_mono.mid.
# I0618 11:01:40.486086 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_31_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_32_mono.mid.
# I0618 11:01:40.525978 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_32_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_33_mono.mid.
# I0618 11:01:40.567865 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_33_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_34_mono.mid.
# I0618 11:01:40.620724 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_34_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_36_mono.mid.
# I0618 11:01:40.687546 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_36_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_37_mono.mid.
# I0618 11:01:40.781298 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_37_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_38_mono.mid.
# I0618 11:01:40.930901 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_38_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_39_mono.mid.
# I0618 11:01:41.057564 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_39_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_40_mono.mid.
# I0618 11:01:41.138350 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_40_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_41_mono.mid.
# I0618 11:01:41.270997 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_41_mono.mid.
# INFO:tensorflow:Converted MIDI file ./partituras_midi\solea_input_42_mono.mid.
# I0618 11:01:41.370735 14788 convert_dir_to_note_sequences.py:153] Converted MIDI file ./partituras_midi\solea_input_42_mono.mid.

# %%
input_dir="./melody_rnn/data/notesequences.tf.record"
output_dir="./melody_rnn/data"

####################### CREACION DEL DATASET CON LAS PARTITURAS A PARTIR DE TF.RECORD ###################
# !melody_rnn_create_dataset \
--config=$configuracion_base \
--input=$input_dir \
--output_dir=$output_dir \
--eval_ratio=0.0
# Out:
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\pipelines\pipeline.py:310: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W0618 11:02:07.300456  1316 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\pipelines\pipeline.py:310: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:tensorflow:
#
# Completed.
#
# I0618 11:02:18.202301  1316 pipeline.py:386]
#
# Completed.
#
# INFO:tensorflow:Processed 40 inputs total. Produced 41 outputs.
# I0618 11:02:18.202301  1316 pipeline.py:387] Processed 40 inputs total. Produced 41 outputs.
# INFO:tensorflow:DAGPipeline_MelodyExtractor_training_melodies_discarded_too_few_pitches: 1
# I0618 11:02:18.202301  1316 statistics.py:137] DAGPipeline_MelodyExtractor_training_melodies_discarded_too_few_pitches: 1
# INFO:tensorflow:DAGPipeline_MelodyExtractor_training_melodies_discarded_too_long: 0
# I0618 11:02:18.203300  1316 statistics.py:137] DAGPipeline_MelodyExtractor_training_melodies_discarded_too_long: 0
# INFO:tensorflow:DAGPipeline_MelodyExtractor_training_melodies_discarded_too_short: 3
# I0618 11:02:18.203300  1316 statistics.py:137] DAGPipeline_MelodyExtractor_training_melodies_discarded_too_short: 3
# INFO:tensorflow:DAGPipeline_MelodyExtractor_training_melodies_truncated: 7
# I0618 11:02:18.203300  1316 statistics.py:137] DAGPipeline_MelodyExtractor_training_melodies_truncated: 7
# INFO:tensorflow:DAGPipeline_MelodyExtractor_training_melody_lengths_in_bars:
#   [10,20): 18
#   [20,30): 8
#   [30,40): 5
#   [40,50): 10
# I0618 11:02:18.203300  1316 statistics.py:137] DAGPipeline_MelodyExtractor_training_melody_lengths_in_bars:
#   [10,20): 18
#   [20,30): 8
#   [30,40): 5
#   [40,50): 10
# INFO:tensorflow:DAGPipeline_MelodyExtractor_training_polyphonic_tracks_discarded: 0
# I0618 11:02:18.203300  1316 statistics.py:137] DAGPipeline_MelodyExtractor_training_polyphonic_tracks_discarded: 0
# INFO:tensorflow:DAGPipeline_RandomPartition_training_melodies_count: 40
# I0618 11:02:18.203300  1316 statistics.py:137] DAGPipeline_RandomPartition_training_melodies_count: 40
# INFO:tensorflow:DAGPipeline_TranspositionPipeline_training_skipped_due_to_range_exceeded: 0
# I0618 11:02:18.203300  1316 statistics.py:137] DAGPipeline_TranspositionPipeline_training_skipped_due_to_range_exceeded: 0
# INFO:tensorflow:DAGPipeline_TranspositionPipeline_training_transpositions_generated: 40
# I0618 11:02:18.203300  1316 statistics.py:137] DAGPipeline_TranspositionPipeline_training_transpositions_generated: 40

# %%
input_file_training="./melody_rnn/data/training_melodies.tfrecord"
logdir="./melody_rnn/logdir/run1"

######################## TRAINING DEL MODELO ############################

# !melody_rnn_train \
--config=$configuracion_base \
--run_dir=$logdir \
--sequence_example_file=$input_file_training \
--hparams="batch_size=64, rnn_layer_sizes=[64,64]" \
--num_training_steps=21000
# Out:
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# INFO:tensorflow:hparams = {'batch_size': 64, 'rnn_layer_sizes': [64, 64], 'dropout_keep_prob': 0.5, 'attn_length': 0, 'clip_norm': 5, 'learning_rate': 0.001, 'residual_connections': False, 'use_cudnn': False}
# I0618 11:09:19.909124 17052 events_rnn_graph.py:96] hparams = {'batch_size': 64, 'rnn_layer_sizes': [64, 64], 'dropout_keep_prob': 0.5, 'attn_length': 0, 'clip_norm': 5, 'learning_rate': 0.001, 'residual_connections': False, 'use_cudnn': False}
# INFO:tensorflow:Train dir: ./melody_rnn/logdir/run1\train
# I0618 11:09:19.910121 17052 melody_rnn_train.py:87] Train dir: ./melody_rnn/logdir/run1\train
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\common\sequence_example_lib.py:66: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0618 11:09:19.912116 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\common\sequence_example_lib.py:66: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\input.py:267: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0618 11:09:19.929071 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\input.py:267: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# W0618 11:09:19.931069 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\input.py:197: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0618 11:09:19.938050 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\input.py:197: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\input.py:196: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0618 11:09:19.941040 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\input.py:196: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\common\sequence_example_lib.py:67: TFRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# W0618 11:09:19.989910 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\common\sequence_example_lib.py:67: TFRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# INFO:tensorflow:Counting records in .\melody_rnn\data\training_melodies.tfrecord.
# I0618 11:09:20.080672 17052 sequence_example_lib.py:121] Counting records in .\melody_rnn\data\training_melodies.tfrecord.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\common\sequence_example_lib.py:122: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W0618 11:09:20.081667 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\common\sequence_example_lib.py:122: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:tensorflow:Total records: 41
# I0618 11:09:20.110591 17052 sequence_example_lib.py:127] Total records: 41
# INFO:tensorflow:[<tf.Tensor 'random_shuffle_queue_Dequeue:0' shape=(?, 38) dtype=float32>, <tf.Tensor 'random_shuffle_queue_Dequeue:1' shape=(?,) dtype=int64>, <tf.Tensor 'random_shuffle_queue_Dequeue:2' shape=() dtype=int32>]
# I0618 11:09:20.141509 17052 sequence_example_lib.py:99] [<tf.Tensor 'random_shuffle_queue_Dequeue:0' shape=(?, 38) dtype=float32>, <tf.Tensor 'random_shuffle_queue_Dequeue:1' shape=(?,) dtype=int64>, <tf.Tensor 'random_shuffle_queue_Dequeue:2' shape=() dtype=int32>]
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\common\sequence_example_lib.py:100: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# W0618 11:09:20.142506 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\common\sequence_example_lib.py:100: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:50: BasicLSTMCell.__init__ (from tensorflow.python.keras.layers.legacy_rnn.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0618 11:09:20.188385 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:50: BasicLSTMCell.__init__ (from tensorflow.python.keras.layers.legacy_rnn.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:63: MultiRNNCell.__init__ (from tensorflow.python.keras.layers.legacy_rnn.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# W0618 11:09:20.235261 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:63: MultiRNNCell.__init__ (from tensorflow.python.keras.layers.legacy_rnn.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:137: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0618 11:09:20.314058 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:137: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:738: Layer.add_variable (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0618 11:09:20.525492 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:738: Layer.add_variable (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:744: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0618 11:09:20.549428 17052 deprecation.py:500] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:744: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tf_slim\layers\layers.py:1898: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0618 11:09:20.778822 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tf_slim\layers\layers.py:1898: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:172: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0618 11:09:21.146847 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:172: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:185: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0618 11:09:21.160810 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:185: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Starting training loop...
# I0618 11:09:22.828396 17052 events_rnn_train.py:103] Starting training loop...
# INFO:tensorflow:Create CheckpointSaverHook.
# I0618 11:09:22.828396 17052 basic_session_run_hooks.py:546] Create CheckpointSaverHook.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\training_util.py:235: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0618 11:09:26.681191 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\training_util.py:235: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Graph was finalized.
# I0618 11:09:27.285592 17052 monitored_session.py:246] Graph was finalized.
# 2021-06-18 11:09:27.288234: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Restoring parameters from ./melody_rnn/logdir/run1\train\model.ckpt-20387
# I0618 11:09:27.321497 17052 saver.py:1293] Restoring parameters from ./melody_rnn/logdir/run1\train\model.ckpt-20387
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\saver.py:1077: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# W0618 11:09:27.460130 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\saver.py:1077: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# I0618 11:09:27.573828 17052 session_manager.py:505] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0618 11:09:27.593777 17052 session_manager.py:508] Done running local_init_op.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\monitored_session.py:906: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0618 11:09:27.648630 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\monitored_session.py:906: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20387...
# I0618 11:09:34.203169 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20387...
# INFO:tensorflow:Saving checkpoints for 20387 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:09:34.205163 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20387 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20387...
# I0618 11:09:36.873543 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20387...
# INFO:tensorflow:Accuracy = 0.8380977, Global Step = 20388, Loss = 0.4726582, Perplexity = 1.6042529
# I0618 11:09:38.507756 17052 basic_session_run_hooks.py:262] Accuracy = 0.8380977, Global Step = 20388, Loss = 0.4726582, Perplexity = 1.6042529
# INFO:tensorflow:Accuracy = 0.8418071, Global Step = 20398, Loss = 0.46678993, Perplexity = 1.5948664 (12.646 sec)
# I0618 11:09:51.154006 17052 basic_session_run_hooks.py:260] Accuracy = 0.8418071, Global Step = 20398, Loss = 0.46678993, Perplexity = 1.5948664 (12.646 sec)
# INFO:tensorflow:global_step/sec: 0.790748
# I0618 11:09:51.155005 17052 basic_session_run_hooks.py:702] global_step/sec: 0.790748
# INFO:tensorflow:Accuracy = 0.83986723, Global Step = 20408, Loss = 0.46026328, Perplexity = 1.5844911 (14.375 sec)
# I0618 11:10:05.528574 17052 basic_session_run_hooks.py:260] Accuracy = 0.83986723, Global Step = 20408, Loss = 0.46026328, Perplexity = 1.5844911 (14.375 sec)
# INFO:tensorflow:global_step/sec: 0.695625
# I0618 11:10:05.530569 17052 basic_session_run_hooks.py:702] global_step/sec: 0.695625
# INFO:tensorflow:Accuracy = 0.83567107, Global Step = 20418, Loss = 0.4672642, Perplexity = 1.5956229 (15.165 sec)
# I0618 11:10:20.693125 17052 basic_session_run_hooks.py:260] Accuracy = 0.83567107, Global Step = 20418, Loss = 0.4672642, Perplexity = 1.5956229 (15.165 sec)
# INFO:tensorflow:global_step/sec: 0.659433
# I0618 11:10:20.696117 17052 basic_session_run_hooks.py:702] global_step/sec: 0.659433
# INFO:tensorflow:Accuracy = 0.84534264, Global Step = 20428, Loss = 0.4554526, Perplexity = 1.5768869 (13.590 sec)
# I0618 11:10:34.283073 17052 basic_session_run_hooks.py:260] Accuracy = 0.84534264, Global Step = 20428, Loss = 0.4554526, Perplexity = 1.5768869 (13.590 sec)
# INFO:tensorflow:global_step/sec: 0.735838
# I0618 11:10:34.285068 17052 basic_session_run_hooks.py:702] global_step/sec: 0.735838
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20430...
# I0618 11:10:37.023816 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20430...
# INFO:tensorflow:Saving checkpoints for 20430 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:10:37.024815 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20430 into ./melody_rnn/logdir/run1\train\model.ckpt.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\saver.py:969: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# W0618 11:10:37.123553 17052 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\saver.py:969: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20430...
# I0618 11:10:39.892759 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20430...
# INFO:tensorflow:Accuracy = 0.8263826, Global Step = 20438, Loss = 0.5099459, Perplexity = 1.6652012 (16.732 sec)
# I0618 11:10:51.014852 17052 basic_session_run_hooks.py:260] Accuracy = 0.8263826, Global Step = 20438, Loss = 0.5099459, Perplexity = 1.6652012 (16.732 sec)
# INFO:tensorflow:global_step/sec: 0.597701
# I0618 11:10:51.016846 17052 basic_session_run_hooks.py:702] global_step/sec: 0.597701
# INFO:tensorflow:Accuracy = 0.7918251, Global Step = 20448, Loss = 0.631501, Perplexity = 1.880431 (15.187 sec)
# I0618 11:11:06.201579 17052 basic_session_run_hooks.py:260] Accuracy = 0.7918251, Global Step = 20448, Loss = 0.631501, Perplexity = 1.880431 (15.187 sec)
# INFO:tensorflow:global_step/sec: 0.658427
# I0618 11:11:06.204571 17052 basic_session_run_hooks.py:702] global_step/sec: 0.658427
# INFO:tensorflow:Accuracy = 0.76407987, Global Step = 20458, Loss = 0.8024402, Perplexity = 2.2309785 (18.957 sec)
# I0618 11:11:25.158380 17052 basic_session_run_hooks.py:260] Accuracy = 0.76407987, Global Step = 20458, Loss = 0.8024402, Perplexity = 2.2309785 (18.957 sec)
# INFO:tensorflow:global_step/sec: 0.527487
# I0618 11:11:25.161371 17052 basic_session_run_hooks.py:702] global_step/sec: 0.527487
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20465...
# I0618 11:11:38.085399 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20465...
# INFO:tensorflow:Saving checkpoints for 20465 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:11:38.085399 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20465 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20465...
# I0618 11:11:41.321817 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20465...
# INFO:tensorflow:Accuracy = 0.7411857, Global Step = 20468, Loss = 0.9054725, Perplexity = 2.4731002 (19.772 sec)
# I0618 11:11:44.930295 17052 basic_session_run_hooks.py:260] Accuracy = 0.7411857, Global Step = 20468, Loss = 0.9054725, Perplexity = 2.4731002 (19.772 sec)
# INFO:tensorflow:global_step/sec: 0.505742
# I0618 11:11:44.934283 17052 basic_session_run_hooks.py:702] global_step/sec: 0.505742
# INFO:tensorflow:Accuracy = 0.7474926, Global Step = 20478, Loss = 0.8081864, Perplexity = 2.243835 (17.456 sec)
# I0618 11:12:02.385924 17052 basic_session_run_hooks.py:260] Accuracy = 0.7474926, Global Step = 20478, Loss = 0.8081864, Perplexity = 2.243835 (17.456 sec)
# INFO:tensorflow:global_step/sec: 0.572947
# I0618 11:12:02.387919 17052 basic_session_run_hooks.py:702] global_step/sec: 0.572947
# INFO:tensorflow:global_step/sec: 0.622566
# I0618 11:12:19.132336 17052 basic_session_run_hooks.py:702] global_step/sec: 0.622566
# INFO:tensorflow:Accuracy = 0.78442687, Global Step = 20488, Loss = 0.67710185, Perplexity = 1.9681654 (16.748 sec)
# I0618 11:12:19.134330 17052 basic_session_run_hooks.py:260] Accuracy = 0.78442687, Global Step = 20488, Loss = 0.67710185, Perplexity = 1.9681654 (16.748 sec)
# INFO:tensorflow:global_step/sec: 0.597072
# I0618 11:12:19.136324 17052 basic_session_run_hooks.py:702] global_step/sec: 0.597072
# INFO:tensorflow:Accuracy = 0.7945265, Global Step = 20498, Loss = 0.60527736, Perplexity = 1.8317602 (15.457 sec)
# I0618 11:12:34.591228 17052 basic_session_run_hooks.py:260] Accuracy = 0.7945265, Global Step = 20498, Loss = 0.60527736, Perplexity = 1.8317602 (15.457 sec)
# INFO:tensorflow:global_step/sec: 0.64696
# I0618 11:12:34.593219 17052 basic_session_run_hooks.py:702] global_step/sec: 0.64696
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20500...
# I0618 11:12:38.745165 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20500...
# INFO:tensorflow:Saving checkpoints for 20500 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:12:38.746163 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20500 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20500...
# I0618 11:12:42.864199 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20500...
# INFO:tensorflow:Accuracy = 0.80906886, Global Step = 20508, Loss = 0.5714405, Perplexity = 1.7708161 (20.422 sec)
# I0618 11:12:55.012886 17052 basic_session_run_hooks.py:260] Accuracy = 0.80906886, Global Step = 20508, Loss = 0.5714405, Perplexity = 1.7708161 (20.422 sec)
# INFO:tensorflow:global_step/sec: 0.489628
# I0618 11:12:55.016877 17052 basic_session_run_hooks.py:702] global_step/sec: 0.489628
# INFO:tensorflow:Accuracy = 0.80257833, Global Step = 20518, Loss = 0.57416695, Perplexity = 1.7756507 (16.960 sec)
# I0618 11:13:11.972758 17052 basic_session_run_hooks.py:260] Accuracy = 0.80257833, Global Step = 20518, Loss = 0.57416695, Perplexity = 1.7756507 (16.960 sec)
# INFO:tensorflow:global_step/sec: 0.589696
# I0618 11:13:11.974753 17052 basic_session_run_hooks.py:702] global_step/sec: 0.589696
# INFO:tensorflow:Accuracy = 0.83606476, Global Step = 20528, Loss = 0.48205015, Perplexity = 1.619391 (15.911 sec)
# I0618 11:13:27.883907 17052 basic_session_run_hooks.py:260] Accuracy = 0.83606476, Global Step = 20528, Loss = 0.48205015, Perplexity = 1.619391 (15.911 sec)
# INFO:tensorflow:global_step/sec: 0.628451
# I0618 11:13:27.887897 17052 basic_session_run_hooks.py:702] global_step/sec: 0.628451
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20535...
# I0618 11:13:39.040726 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20535...
# INFO:tensorflow:Saving checkpoints for 20535 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:13:39.041728 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20535 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20535...
# I0618 11:13:43.075981 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20535...
# INFO:tensorflow:Accuracy = 0.8287592, Global Step = 20538, Loss = 0.49747083, Perplexity = 1.6445566 (19.729 sec)
# I0618 11:13:47.612904 17052 basic_session_run_hooks.py:260] Accuracy = 0.8287592, Global Step = 20538, Loss = 0.49747083, Perplexity = 1.6445566 (19.729 sec)
# INFO:tensorflow:global_step/sec: 0.506919
# I0618 11:13:47.613901 17052 basic_session_run_hooks.py:702] global_step/sec: 0.506919
# INFO:tensorflow:Accuracy = 0.8062758, Global Step = 20548, Loss = 0.5630323, Perplexity = 1.7559892 (15.012 sec)
# I0618 11:14:02.624505 17052 basic_session_run_hooks.py:260] Accuracy = 0.8062758, Global Step = 20548, Loss = 0.5630323, Perplexity = 1.7559892 (15.012 sec)
# INFO:tensorflow:global_step/sec: 0.666151
# I0618 11:14:02.626500 17052 basic_session_run_hooks.py:702] global_step/sec: 0.666151
# INFO:tensorflow:Accuracy = 0.81895036, Global Step = 20558, Loss = 0.5342736, Perplexity = 1.7062085 (14.481 sec)
# I0618 11:14:17.105025 17052 basic_session_run_hooks.py:260] Accuracy = 0.81895036, Global Step = 20558, Loss = 0.5342736, Perplexity = 1.7062085 (14.481 sec)
# INFO:tensorflow:global_step/sec: 0.690535
# I0618 11:14:17.107020 17052 basic_session_run_hooks.py:702] global_step/sec: 0.690535
# INFO:tensorflow:Accuracy = 0.8313354, Global Step = 20568, Loss = 0.48997673, Perplexity = 1.6322782 (14.597 sec)
# I0618 11:14:31.702222 17052 basic_session_run_hooks.py:260] Accuracy = 0.8313354, Global Step = 20568, Loss = 0.48997673, Perplexity = 1.6322782 (14.597 sec)
# INFO:tensorflow:global_step/sec: 0.68511
# I0618 11:14:31.704216 17052 basic_session_run_hooks.py:702] global_step/sec: 0.68511
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20574...
# I0618 11:14:39.868105 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20574...
# INFO:tensorflow:Saving checkpoints for 20574 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:14:39.868105 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20574 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20574...
# I0618 11:14:42.419321 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20574...
# INFO:tensorflow:Accuracy = 0.8326048, Global Step = 20578, Loss = 0.4928462, Perplexity = 1.6369687 (14.998 sec)
# I0618 11:14:46.699924 17052 basic_session_run_hooks.py:260] Accuracy = 0.8326048, Global Step = 20578, Loss = 0.4928462, Perplexity = 1.6369687 (14.998 sec)
# INFO:tensorflow:global_step/sec: 0.666725
# I0618 11:14:46.701916 17052 basic_session_run_hooks.py:702] global_step/sec: 0.666725
# INFO:tensorflow:global_step/sec: 0.613697
# I0618 11:15:02.079066 17052 basic_session_run_hooks.py:702] global_step/sec: 0.613697
# INFO:tensorflow:Accuracy = 0.839373, Global Step = 20588, Loss = 0.47012532, Perplexity = 1.6001947 (15.381 sec)
# I0618 11:15:02.081061 17052 basic_session_run_hooks.py:260] Accuracy = 0.839373, Global Step = 20588, Loss = 0.47012532, Perplexity = 1.6001947 (15.381 sec)
# INFO:tensorflow:global_step/sec: 0.650147
# I0618 11:15:02.083055 17052 basic_session_run_hooks.py:702] global_step/sec: 0.650147
# INFO:tensorflow:Accuracy = 0.84025604, Global Step = 20598, Loss = 0.47211212, Perplexity = 1.6033771 (14.929 sec)
# I0618 11:15:17.010382 17052 basic_session_run_hooks.py:260] Accuracy = 0.84025604, Global Step = 20598, Loss = 0.47211212, Perplexity = 1.6033771 (14.929 sec)
# INFO:tensorflow:global_step/sec: 0.669823
# I0618 11:15:17.013375 17052 basic_session_run_hooks.py:702] global_step/sec: 0.669823
# INFO:tensorflow:Accuracy = 0.8366646, Global Step = 20608, Loss = 0.48162794, Perplexity = 1.6187074 (15.258 sec)
# I0618 11:15:32.268755 17052 basic_session_run_hooks.py:260] Accuracy = 0.8366646, Global Step = 20608, Loss = 0.48162794, Perplexity = 1.6187074 (15.258 sec)
# INFO:tensorflow:global_step/sec: 0.655292
# I0618 11:15:32.272745 17052 basic_session_run_hooks.py:702] global_step/sec: 0.655292
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20614...
# I0618 11:15:40.338270 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20614...
# INFO:tensorflow:Saving checkpoints for 20614 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:15:40.339267 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20614 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20614...
# I0618 11:15:43.265557 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20614...
# INFO:tensorflow:Accuracy = 0.8368931, Global Step = 20618, Loss = 0.46808127, Perplexity = 1.5969272 (15.547 sec)
# I0618 11:15:47.815536 17052 basic_session_run_hooks.py:260] Accuracy = 0.8368931, Global Step = 20618, Loss = 0.46808127, Perplexity = 1.5969272 (15.547 sec)
# INFO:tensorflow:global_step/sec: 0.643344
# I0618 11:15:47.816534 17052 basic_session_run_hooks.py:702] global_step/sec: 0.643344
# INFO:tensorflow:Accuracy = 0.8255264, Global Step = 20628, Loss = 0.5046405, Perplexity = 1.65639 (14.326 sec)
# I0618 11:16:02.141393 17052 basic_session_run_hooks.py:260] Accuracy = 0.8255264, Global Step = 20628, Loss = 0.5046405, Perplexity = 1.65639 (14.326 sec)
# INFO:tensorflow:global_step/sec: 0.697989
# I0618 11:16:02.143403 17052 basic_session_run_hooks.py:702] global_step/sec: 0.697989
# INFO:tensorflow:Accuracy = 0.83296627, Global Step = 20638, Loss = 0.4790947, Perplexity = 1.6146121 (14.161 sec)
# I0618 11:16:16.302201 17052 basic_session_run_hooks.py:260] Accuracy = 0.83296627, Global Step = 20638, Loss = 0.4790947, Perplexity = 1.6146121 (14.161 sec)
# INFO:tensorflow:global_step/sec: 0.706175
# I0618 11:16:16.304195 17052 basic_session_run_hooks.py:702] global_step/sec: 0.706175
# INFO:tensorflow:Accuracy = 0.8334546, Global Step = 20648, Loss = 0.4854494, Perplexity = 1.6249051 (14.784 sec)
# I0618 11:16:31.085867 17052 basic_session_run_hooks.py:260] Accuracy = 0.8334546, Global Step = 20648, Loss = 0.4854494, Perplexity = 1.6249051 (14.784 sec)
# INFO:tensorflow:global_step/sec: 0.676468
# I0618 11:16:31.087862 17052 basic_session_run_hooks.py:702] global_step/sec: 0.676468
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20655...
# I0618 11:16:41.825273 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20655...
# INFO:tensorflow:Saving checkpoints for 20655 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:16:41.825273 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20655 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20655...
# I0618 11:16:44.846229 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20655...
# INFO:tensorflow:Accuracy = 0.8399877, Global Step = 20658, Loss = 0.47961476, Perplexity = 1.6154519 (17.867 sec)
# I0618 11:16:48.953323 17052 basic_session_run_hooks.py:260] Accuracy = 0.8399877, Global Step = 20658, Loss = 0.47961476, Perplexity = 1.6154519 (17.867 sec)
# INFO:tensorflow:global_step/sec: 0.559646
# I0618 11:16:48.955317 17052 basic_session_run_hooks.py:702] global_step/sec: 0.559646
# INFO:tensorflow:Accuracy = 0.84082717, Global Step = 20668, Loss = 0.45251447, Perplexity = 1.5722606 (16.479 sec)
# I0618 11:17:05.432426 17052 basic_session_run_hooks.py:260] Accuracy = 0.84082717, Global Step = 20668, Loss = 0.45251447, Perplexity = 1.5722606 (16.479 sec)
# INFO:tensorflow:global_step/sec: 0.606792
# I0618 11:17:05.435421 17052 basic_session_run_hooks.py:702] global_step/sec: 0.606792
# INFO:tensorflow:Accuracy = 0.82852995, Global Step = 20678, Loss = 0.49746475, Perplexity = 1.6445466 (16.160 sec)
# I0618 11:17:21.592303 17052 basic_session_run_hooks.py:260] Accuracy = 0.82852995, Global Step = 20678, Loss = 0.49746475, Perplexity = 1.6445466 (16.160 sec)
# INFO:tensorflow:global_step/sec: 0.618893
# I0618 11:17:21.594298 17052 basic_session_run_hooks.py:702] global_step/sec: 0.618893
# INFO:tensorflow:global_step/sec: 0.644789
# I0618 11:17:37.168467 17052 basic_session_run_hooks.py:702] global_step/sec: 0.644789
# INFO:tensorflow:Accuracy = 0.83190197, Global Step = 20688, Loss = 0.48739296, Perplexity = 1.6280663 (15.580 sec)
# I0618 11:17:37.172456 17052 basic_session_run_hooks.py:260] Accuracy = 0.83190197, Global Step = 20688, Loss = 0.48739296, Perplexity = 1.6280663 (15.580 sec)
# INFO:tensorflow:global_step/sec: 0.641801
# I0618 11:17:37.174453 17052 basic_session_run_hooks.py:702] global_step/sec: 0.641801
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20692...
# I0618 11:17:42.663319 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20692...
# INFO:tensorflow:Saving checkpoints for 20692 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:17:42.663319 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20692 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20692...
# I0618 11:17:44.360790 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20692...
# INFO:tensorflow:Accuracy = 0.83935016, Global Step = 20698, Loss = 0.4676796, Perplexity = 1.5962858 (15.988 sec)
# I0618 11:17:53.160338 17052 basic_session_run_hooks.py:260] Accuracy = 0.83935016, Global Step = 20698, Loss = 0.4676796, Perplexity = 1.5962858 (15.988 sec)
# INFO:tensorflow:global_step/sec: 0.625474
# I0618 11:17:53.162332 17052 basic_session_run_hooks.py:702] global_step/sec: 0.625474
# INFO:tensorflow:Accuracy = 0.84170145, Global Step = 20708, Loss = 0.46185678, Perplexity = 1.587018 (13.766 sec)
# I0618 11:18:06.926149 17052 basic_session_run_hooks.py:260] Accuracy = 0.84170145, Global Step = 20708, Loss = 0.46185678, Perplexity = 1.587018 (13.766 sec)
# INFO:tensorflow:global_step/sec: 0.72649
# I0618 11:18:06.928144 17052 basic_session_run_hooks.py:702] global_step/sec: 0.72649
# INFO:tensorflow:Accuracy = 0.82522124, Global Step = 20718, Loss = 0.5022844, Perplexity = 1.6524919 (13.314 sec)
# I0618 11:18:20.241616 17052 basic_session_run_hooks.py:260] Accuracy = 0.82522124, Global Step = 20718, Loss = 0.5022844, Perplexity = 1.6524919 (13.314 sec)
# INFO:tensorflow:global_step/sec: 0.751006
# I0618 11:18:20.242614 17052 basic_session_run_hooks.py:702] global_step/sec: 0.751006
# INFO:tensorflow:Accuracy = 0.82901883, Global Step = 20728, Loss = 0.49018967, Perplexity = 1.6326258 (14.103 sec)
# I0618 11:18:34.343121 17052 basic_session_run_hooks.py:260] Accuracy = 0.82901883, Global Step = 20728, Loss = 0.49018967, Perplexity = 1.6326258 (14.103 sec)
# INFO:tensorflow:global_step/sec: 0.709144
# I0618 11:18:34.344118 17052 basic_session_run_hooks.py:702] global_step/sec: 0.709144
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20734...
# I0618 11:18:42.922255 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20734...
# INFO:tensorflow:Saving checkpoints for 20734 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:18:42.922255 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20734 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20734...
# I0618 11:18:45.265999 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20734...
# INFO:tensorflow:Accuracy = 0.8359983, Global Step = 20738, Loss = 0.47774947, Perplexity = 1.6124414 (15.917 sec)
# I0618 11:18:50.260190 17052 basic_session_run_hooks.py:260] Accuracy = 0.8359983, Global Step = 20738, Loss = 0.47774947, Perplexity = 1.6124414 (15.917 sec)
# INFO:tensorflow:global_step/sec: 0.628256
# I0618 11:18:50.261187 17052 basic_session_run_hooks.py:702] global_step/sec: 0.628256
# INFO:tensorflow:Accuracy = 0.8426702, Global Step = 20748, Loss = 0.45900664, Perplexity = 1.5825012 (14.292 sec)
# I0618 11:19:04.552107 17052 basic_session_run_hooks.py:260] Accuracy = 0.8426702, Global Step = 20748, Loss = 0.45900664, Perplexity = 1.5825012 (14.292 sec)
# INFO:tensorflow:global_step/sec: 0.699647
# I0618 11:19:04.554103 17052 basic_session_run_hooks.py:702] global_step/sec: 0.699647
# INFO:tensorflow:Accuracy = 0.83258927, Global Step = 20758, Loss = 0.49073628, Perplexity = 1.6335185 (14.978 sec)
# I0618 11:19:19.529831 17052 basic_session_run_hooks.py:260] Accuracy = 0.83258927, Global Step = 20758, Loss = 0.49073628, Perplexity = 1.6335185 (14.978 sec)
# INFO:tensorflow:global_step/sec: 0.667703
# I0618 11:19:19.531826 17052 basic_session_run_hooks.py:702] global_step/sec: 0.667703
# INFO:tensorflow:Accuracy = 0.84067005, Global Step = 20768, Loss = 0.45641342, Perplexity = 1.5784028 (15.317 sec)
# I0618 11:19:34.846941 17052 basic_session_run_hooks.py:260] Accuracy = 0.84067005, Global Step = 20768, Loss = 0.45641342, Perplexity = 1.5784028 (15.317 sec)
# INFO:tensorflow:global_step/sec: 0.652822
# I0618 11:19:34.848937 17052 basic_session_run_hooks.py:702] global_step/sec: 0.652822
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20774...
# I0618 11:19:43.307385 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20774...
# INFO:tensorflow:Saving checkpoints for 20774 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:19:43.307385 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20774 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20774...
# I0618 11:19:45.307078 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20774...
# INFO:tensorflow:Accuracy = 0.82862586, Global Step = 20778, Loss = 0.4986013, Perplexity = 1.6464168 (15.933 sec)
# I0618 11:19:50.780025 17052 basic_session_run_hooks.py:260] Accuracy = 0.82862586, Global Step = 20778, Loss = 0.4986013, Perplexity = 1.6464168 (15.933 sec)
# INFO:tensorflow:global_step/sec: 0.627664
# I0618 11:19:50.782016 17052 basic_session_run_hooks.py:702] global_step/sec: 0.627664
# INFO:tensorflow:global_step/sec: 0.674991
# I0618 11:20:05.318634 17052 basic_session_run_hooks.py:702] global_step/sec: 0.674991
# INFO:tensorflow:Accuracy = 0.81496954, Global Step = 20788, Loss = 0.5382864, Perplexity = 1.7130688 (14.541 sec)
# I0618 11:20:05.320628 17052 basic_session_run_hooks.py:260] Accuracy = 0.81496954, Global Step = 20788, Loss = 0.5382864, Perplexity = 1.7130688 (14.541 sec)
# INFO:tensorflow:global_step/sec: 0.687682
# I0618 11:20:05.322623 17052 basic_session_run_hooks.py:702] global_step/sec: 0.687682
# INFO:tensorflow:Accuracy = 0.8423353, Global Step = 20798, Loss = 0.4628207, Perplexity = 1.5885485 (13.090 sec)
# I0618 11:20:18.410218 17052 basic_session_run_hooks.py:260] Accuracy = 0.8423353, Global Step = 20798, Loss = 0.4628207, Perplexity = 1.5885485 (13.090 sec)
# INFO:tensorflow:global_step/sec: 0.763966
# I0618 11:20:18.412212 17052 basic_session_run_hooks.py:702] global_step/sec: 0.763966
# INFO:tensorflow:Accuracy = 0.8298707, Global Step = 20808, Loss = 0.49155366, Perplexity = 1.6348543 (13.822 sec)
# I0618 11:20:32.231726 17052 basic_session_run_hooks.py:260] Accuracy = 0.8298707, Global Step = 20808, Loss = 0.49155366, Perplexity = 1.6348543 (13.822 sec)
# INFO:tensorflow:global_step/sec: 0.72351
# I0618 11:20:32.233722 17052 basic_session_run_hooks.py:702] global_step/sec: 0.72351
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20816...
# I0618 11:20:43.658822 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20816...
# INFO:tensorflow:Saving checkpoints for 20816 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:20:43.658822 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20816 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20816...
# I0618 11:20:45.472009 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20816...
# INFO:tensorflow:Accuracy = 0.85484356, Global Step = 20818, Loss = 0.42290092, Perplexity = 1.526383 (15.571 sec)
# I0618 11:20:47.802784 17052 basic_session_run_hooks.py:260] Accuracy = 0.85484356, Global Step = 20818, Loss = 0.42290092, Perplexity = 1.526383 (15.571 sec)
# INFO:tensorflow:global_step/sec: 0.642258
# I0618 11:20:47.804779 17052 basic_session_run_hooks.py:702] global_step/sec: 0.642258
# INFO:tensorflow:Accuracy = 0.8502123, Global Step = 20828, Loss = 0.44613665, Perplexity = 1.5622649 (13.865 sec)
# I0618 11:21:01.667343 17052 basic_session_run_hooks.py:260] Accuracy = 0.8502123, Global Step = 20828, Loss = 0.44613665, Perplexity = 1.5622649 (13.865 sec)
# INFO:tensorflow:global_step/sec: 0.721212
# I0618 11:21:01.669338 17052 basic_session_run_hooks.py:702] global_step/sec: 0.721212
# INFO:tensorflow:Accuracy = 0.8345703, Global Step = 20838, Loss = 0.49026003, Perplexity = 1.6327407 (14.197 sec)
# I0618 11:21:15.863985 17052 basic_session_run_hooks.py:260] Accuracy = 0.8345703, Global Step = 20838, Loss = 0.49026003, Perplexity = 1.6327407 (14.197 sec)
# INFO:tensorflow:global_step/sec: 0.704392
# I0618 11:21:15.865980 17052 basic_session_run_hooks.py:702] global_step/sec: 0.704392
# INFO:tensorflow:Accuracy = 0.8269852, Global Step = 20848, Loss = 0.5059861, Perplexity = 1.6586202 (15.113 sec)
# I0618 11:21:30.976616 17052 basic_session_run_hooks.py:260] Accuracy = 0.8269852, Global Step = 20848, Loss = 0.5059861, Perplexity = 1.6586202 (15.113 sec)
# INFO:tensorflow:global_step/sec: 0.661742
# I0618 11:21:30.978611 17052 basic_session_run_hooks.py:702] global_step/sec: 0.661742
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20857...
# I0618 11:21:44.688110 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 20857...
# INFO:tensorflow:Saving checkpoints for 20857 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:21:44.688110 17052 basic_session_run_hooks.py:618] Saving checkpoints for 20857 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20857...
# I0618 11:21:46.951067 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 20857...
# INFO:tensorflow:Accuracy = 0.84269196, Global Step = 20858, Loss = 0.45730743, Perplexity = 1.5798144 (17.404 sec)
# I0618 11:21:48.380843 17052 basic_session_run_hooks.py:260] Accuracy = 0.84269196, Global Step = 20858, Loss = 0.45730743, Perplexity = 1.5798144 (17.404 sec)
# INFO:tensorflow:global_step/sec: 0.57454
# I0618 11:21:48.382841 17052 basic_session_run_hooks.py:702] global_step/sec: 0.57454
# INFO:tensorflow:Accuracy = 0.8378601, Global Step = 20868, Loss = 0.46607244, Perplexity = 1.5937225 (13.553 sec)
# I0618 11:22:01.933837 17052 basic_session_run_hooks.py:260] Accuracy = 0.8378601, Global Step = 20868, Loss = 0.46607244, Perplexity = 1.5937225 (13.553 sec)
# INFO:tensorflow:global_step/sec: 0.737844
# I0618 11:22:01.935832 17052 basic_session_run_hooks.py:702] global_step/sec: 0.737844
# INFO:tensorflow:Accuracy = 0.8369745, Global Step = 20878, Loss = 0.46818435, Perplexity = 1.5970918 (13.065 sec)
# ...
# I0618 11:28:50.057671 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 21155...
# INFO:tensorflow:Accuracy = 0.8294897, Global Step = 21158, Loss = 0.49317098, Perplexity = 1.6375005 (16.625 sec)
# I0618 11:28:54.561195 17052 basic_session_run_hooks.py:260] Accuracy = 0.8294897, Global Step = 21158, Loss = 0.49317098, Perplexity = 1.6375005 (16.625 sec)
# INFO:tensorflow:global_step/sec: 0.601547
# I0618 11:28:54.563189 17052 basic_session_run_hooks.py:702] global_step/sec: 0.601547
# INFO:tensorflow:Accuracy = 0.8351907, Global Step = 21168, Loss = 0.4698177, Perplexity = 1.5997026 (13.114 sec)
# I0618 11:29:07.675435 17052 basic_session_run_hooks.py:260] Accuracy = 0.8351907, Global Step = 21168, Loss = 0.4698177, Perplexity = 1.5997026 (13.114 sec)
# INFO:tensorflow:global_step/sec: 0.76253
# I0618 11:29:07.677429 17052 basic_session_run_hooks.py:702] global_step/sec: 0.76253
# INFO:tensorflow:Accuracy = 0.81945026, Global Step = 21178, Loss = 0.5422454, Perplexity = 1.7198642 (12.985 sec)
# I0618 11:29:20.659938 17052 basic_session_run_hooks.py:260] Accuracy = 0.81945026, Global Step = 21178, Loss = 0.5422454, Perplexity = 1.7198642 (12.985 sec)
# INFO:tensorflow:global_step/sec: 0.770149
# I0618 11:29:20.660936 17052 basic_session_run_hooks.py:702] global_step/sec: 0.770149
# INFO:tensorflow:global_step/sec: 0.729091
# I0618 11:29:33.905131 17052 basic_session_run_hooks.py:702] global_step/sec: 0.729091
# INFO:tensorflow:Accuracy = 0.81726265, Global Step = 21188, Loss = 0.53844124, Perplexity = 1.7133341 (13.246 sec)
# I0618 11:29:33.906128 17052 basic_session_run_hooks.py:260] Accuracy = 0.81726265, Global Step = 21188, Loss = 0.53844124, Perplexity = 1.7133341 (13.246 sec)
# INFO:tensorflow:global_step/sec: 0.754877
# I0618 11:29:33.908123 17052 basic_session_run_hooks.py:702] global_step/sec: 0.754877
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 21198...
# I0618 11:29:47.707757 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 21198...
# INFO:tensorflow:Saving checkpoints for 21198 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:29:47.708755 17052 basic_session_run_hooks.py:618] Saving checkpoints for 21198 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 21198...
# I0618 11:29:49.468054 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 21198...
# INFO:tensorflow:Accuracy = 0.82472825, Global Step = 21198, Loss = 0.5109678, Perplexity = 1.6669036 (15.564 sec)
# I0618 11:29:49.470048 17052 basic_session_run_hooks.py:260] Accuracy = 0.82472825, Global Step = 21198, Loss = 0.5109678, Perplexity = 1.6669036 (15.564 sec)
# INFO:tensorflow:global_step/sec: 0.642553
# I0618 11:29:49.471046 17052 basic_session_run_hooks.py:702] global_step/sec: 0.642553
# INFO:tensorflow:Accuracy = 0.83987993, Global Step = 21208, Loss = 0.47203624, Perplexity = 1.6032555 (13.092 sec)
# I0618 11:30:02.562242 17052 basic_session_run_hooks.py:260] Accuracy = 0.83987993, Global Step = 21208, Loss = 0.47203624, Perplexity = 1.6032555 (13.092 sec)
# INFO:tensorflow:global_step/sec: 0.763756
# I0618 11:30:02.564235 17052 basic_session_run_hooks.py:702] global_step/sec: 0.763756
# INFO:tensorflow:Accuracy = 0.8384134, Global Step = 21218, Loss = 0.48073664, Perplexity = 1.6172653 (14.899 sec)
# I0618 11:30:17.461012 17052 basic_session_run_hooks.py:260] Accuracy = 0.8384134, Global Step = 21218, Loss = 0.48073664, Perplexity = 1.6172653 (14.899 sec)
# INFO:tensorflow:global_step/sec: 0.671196
# I0618 11:30:17.463006 17052 basic_session_run_hooks.py:702] global_step/sec: 0.671196
# INFO:tensorflow:Accuracy = 0.83751523, Global Step = 21228, Loss = 0.4673617, Perplexity = 1.5957785 (14.250 sec)
# I0618 11:30:31.710997 17052 basic_session_run_hooks.py:260] Accuracy = 0.83751523, Global Step = 21228, Loss = 0.4673617, Perplexity = 1.5957785 (14.250 sec)
# INFO:tensorflow:global_step/sec: 0.701804
# I0618 11:30:31.712988 17052 basic_session_run_hooks.py:702] global_step/sec: 0.701804
# INFO:tensorflow:Accuracy = 0.8360883, Global Step = 21238, Loss = 0.4717456, Perplexity = 1.6027896 (14.864 sec)
# I0618 11:30:46.575065 17052 basic_session_run_hooks.py:260] Accuracy = 0.8360883, Global Step = 21238, Loss = 0.4717456, Perplexity = 1.6027896 (14.864 sec)
# INFO:tensorflow:global_step/sec: 0.672718
# I0618 11:30:46.577065 17052 basic_session_run_hooks.py:702] global_step/sec: 0.672718
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 21239...
# I0618 11:30:47.908046 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 21239...
# INFO:tensorflow:Saving checkpoints for 21239 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:30:47.908046 17052 basic_session_run_hooks.py:618] Saving checkpoints for 21239 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 21239...
# I0618 11:30:50.370186 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 21239...
# INFO:tensorflow:Accuracy = 0.82557905, Global Step = 21248, Loss = 0.5183475, Perplexity = 1.6792504 (15.954 sec)
# I0618 11:31:02.529223 17052 basic_session_run_hooks.py:260] Accuracy = 0.82557905, Global Step = 21248, Loss = 0.5183475, Perplexity = 1.6792504 (15.954 sec)
# INFO:tensorflow:global_step/sec: 0.626835
# I0618 11:31:02.531217 17052 basic_session_run_hooks.py:702] global_step/sec: 0.626835
# INFO:tensorflow:Accuracy = 0.8183895, Global Step = 21258, Loss = 0.55836535, Perplexity = 1.7478131 (12.719 sec)
# I0618 11:31:15.248462 17052 basic_session_run_hooks.py:260] Accuracy = 0.8183895, Global Step = 21258, Loss = 0.55836535, Perplexity = 1.7478131 (12.719 sec)
# INFO:tensorflow:global_step/sec: 0.786149
# I0618 11:31:15.250457 17052 basic_session_run_hooks.py:702] global_step/sec: 0.786149
# INFO:tensorflow:Accuracy = 0.82320297, Global Step = 21268, Loss = 0.5248039, Perplexity = 1.6901274 (14.898 sec)
# I0618 11:31:30.146642 17052 basic_session_run_hooks.py:260] Accuracy = 0.82320297, Global Step = 21268, Loss = 0.5248039, Perplexity = 1.6901274 (14.898 sec)
# INFO:tensorflow:global_step/sec: 0.671223
# I0618 11:31:30.148637 17052 basic_session_run_hooks.py:702] global_step/sec: 0.671223
# INFO:tensorflow:Accuracy = 0.8303483, Global Step = 21278, Loss = 0.4948212, Perplexity = 1.6402049 (13.622 sec)
# I0618 11:31:43.768598 17052 basic_session_run_hooks.py:260] Accuracy = 0.8303483, Global Step = 21278, Loss = 0.4948212, Perplexity = 1.6402049 (13.622 sec)
# INFO:tensorflow:global_step/sec: 0.734109
# I0618 11:31:43.770592 17052 basic_session_run_hooks.py:702] global_step/sec: 0.734109
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 21281...
# I0618 11:31:48.157384 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 21281...
# INFO:tensorflow:Saving checkpoints for 21281 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:31:48.157384 17052 basic_session_run_hooks.py:618] Saving checkpoints for 21281 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 21281...
# I0618 11:31:50.732501 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 21281...
# INFO:tensorflow:global_step/sec: 0.685
# I0618 11:31:59.889595 17052 basic_session_run_hooks.py:702] global_step/sec: 0.685
# INFO:tensorflow:Accuracy = 0.82321954, Global Step = 21288, Loss = 0.5089293, Perplexity = 1.6635091 (16.124 sec)
# I0618 11:31:59.892586 17052 basic_session_run_hooks.py:260] Accuracy = 0.82321954, Global Step = 21288, Loss = 0.5089293, Perplexity = 1.6635091 (16.124 sec)
# INFO:tensorflow:global_step/sec: 0.620232
# I0618 11:31:59.894584 17052 basic_session_run_hooks.py:702] global_step/sec: 0.620232
# INFO:tensorflow:Accuracy = 0.8435617, Global Step = 21298, Loss = 0.46245018, Perplexity = 1.58796 (15.656 sec)
# I0618 11:32:15.548143 17052 basic_session_run_hooks.py:260] Accuracy = 0.8435617, Global Step = 21298, Loss = 0.46245018, Perplexity = 1.58796 (15.656 sec)
# INFO:tensorflow:global_step/sec: 0.638669
# I0618 11:32:15.552135 17052 basic_session_run_hooks.py:702] global_step/sec: 0.638669
# INFO:tensorflow:Accuracy = 0.8425301, Global Step = 21308, Loss = 0.46452042, Perplexity = 1.5912509 (14.171 sec)
# I0618 11:32:29.719231 17052 basic_session_run_hooks.py:260] Accuracy = 0.8425301, Global Step = 21308, Loss = 0.46452042, Perplexity = 1.5912509 (14.171 sec)
# INFO:tensorflow:global_step/sec: 0.705712
# I0618 11:32:29.721225 17052 basic_session_run_hooks.py:702] global_step/sec: 0.705712
# INFO:tensorflow:Accuracy = 0.8430419, Global Step = 21318, Loss = 0.46390733, Perplexity = 1.5902756 (15.397 sec)
# I0618 11:32:45.116232 17052 basic_session_run_hooks.py:260] Accuracy = 0.8430419, Global Step = 21318, Loss = 0.46390733, Perplexity = 1.5902756 (15.397 sec)
# INFO:tensorflow:global_step/sec: 0.649519
# I0618 11:32:45.118227 17052 basic_session_run_hooks.py:702] global_step/sec: 0.649519
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 21321...
# I0618 11:32:49.521124 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 21321...
# INFO:tensorflow:Saving checkpoints for 21321 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:32:49.521124 17052 basic_session_run_hooks.py:618] Saving checkpoints for 21321 into ./melody_rnn/logdir/run1\train\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 21321...
# I0618 11:32:51.406177 17052 basic_session_run_hooks.py:625] Calling checkpoint listeners after saving checkpoint 21321...
# INFO:tensorflow:Accuracy = 0.84828097, Global Step = 21328, Loss = 0.43645057, Perplexity = 1.5472058 (15.408 sec)
# I0618 11:33:00.523950 17052 basic_session_run_hooks.py:260] Accuracy = 0.84828097, Global Step = 21328, Loss = 0.43645057, Perplexity = 1.5472058 (15.408 sec)
# INFO:tensorflow:global_step/sec: 0.649025
# I0618 11:33:00.524947 17052 basic_session_run_hooks.py:702] global_step/sec: 0.649025
# INFO:tensorflow:Accuracy = 0.83773696, Global Step = 21338, Loss = 0.4761543, Perplexity = 1.6098714 (12.984 sec)
# I0618 11:33:13.507960 17052 basic_session_run_hooks.py:260] Accuracy = 0.83773696, Global Step = 21338, Loss = 0.4761543, Perplexity = 1.6098714 (12.984 sec)
# INFO:tensorflow:global_step/sec: 0.770119
# I0618 11:33:13.509953 17052 basic_session_run_hooks.py:702] global_step/sec: 0.770119
# INFO:tensorflow:Accuracy = 0.8389691, Global Step = 21348, Loss = 0.46457538, Perplexity = 1.5913383 (14.125 sec)
# I0618 11:33:27.632529 17052 basic_session_run_hooks.py:260] Accuracy = 0.8389691, Global Step = 21348, Loss = 0.46457538, Perplexity = 1.5913383 (14.125 sec)
# INFO:tensorflow:global_step/sec: 0.707986
# I0618 11:33:27.634524 17052 basic_session_run_hooks.py:702] global_step/sec: 0.707986
# INFO:tensorflow:Accuracy = 0.8473758, Global Step = 21358, Loss = 0.44190407, Perplexity = 1.5556664 (13.840 sec)
# I0618 11:33:41.472199 17052 basic_session_run_hooks.py:260] Accuracy = 0.8473758, Global Step = 21358, Loss = 0.44190407, Perplexity = 1.5556664 (13.840 sec)
# INFO:tensorflow:global_step/sec: 0.722561
# I0618 11:33:41.475191 17052 basic_session_run_hooks.py:702] global_step/sec: 0.722561
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 21365...
# I0618 11:33:50.439333 17052 basic_session_run_hooks.py:613] Calling checkpoint listeners before saving checkpoint 21365...
# INFO:tensorflow:Saving checkpoints for 21365 into ./melody_rnn/logdir/run1\train\model.ckpt.
# I0618 11:33:50.440330 17052 basic_session_run_hooks.py:618] Saving checkpoints for 21365 into ./melody_rnn/logdir/run1\train\model.ckpt.
# Traceback (most recent call last):
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\jose.luis.tapia\Anaconda3\envs\Python38\Scripts\melody_rnn_train.exe\__main__.py", line 7, in <module>
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\melody_rnn\melody_rnn_train.py", line 109, in console_entry_point
#     tf.app.run(main)
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\platform\app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\absl\app.py", line 303, in run
#     _run_main(main, args)
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\absl\app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\melody_rnn\melody_rnn_train.py", line 101, in main
#     events_rnn_train.run_training(build_graph_fn, train_dir,
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_train.py", line 104, in run_training
#     tf_slim.training.train(
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tf_slim\training\training.py", line 551, in train
#     loss = session.run(train_op, run_metadata=run_metadata)
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\monitored_session.py", line 774, in run
#     return self._sess.run(
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\monitored_session.py", line 1279, in run
#     return self._sess.run(
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\monitored_session.py", line 1384, in run
#     raise six.reraise(*original_exc_info)
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\six.py", line 703, in reraise
#     raise value
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\monitored_session.py", line 1369, in run
#     return self._sess.run(*args, **kwargs)
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\monitored_session.py", line 1445, in run
#     hook.after_run(
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\basic_session_run_hooks.py", line 601, in after_run
#     if self._save(run_context.session, global_step):
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\basic_session_run_hooks.py", line 619, in _save
#     self._get_saver().save(session, self._save_path, global_step=step,
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\saver.py", line 1190, in save
#     checkpoint_management.update_checkpoint_state_internal(
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\training\checkpoint_management.py", line 247, in update_checkpoint_state_internal
#     file_io.atomic_write_string_to_file(coord_checkpoint_filename,
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\lib\io\file_io.py", line 570, in atomic_write_string_to_file
#     rename(temp_pathname, filename, overwrite)
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\lib\io\file_io.py", line 529, in rename
#     rename_v2(oldname, newname, overwrite)
#   File "c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\lib\io\file_io.py", line 545, in rename_v2
#     _pywrap_file_io.RenameFile(
# tensorflow.python.framework.errors_impl.UnknownError: Failed to rename: ./melody_rnn/logdir/run1\train\checkpoint.tmpe7d751040b47445a90cda0f3cecb6583 to: ./melody_rnn/logdir/run1\train\checkpoint : Access is denied.
#
# ; Input/output error

# %%
logdir="./melody_rnn/logdir/run1"
output_midi="./melody_rnn/output_midi"

################################ GENERAR MELODIAS #########################

# !melody_rnn_generate \
--config=basic_rnn \
--run_dir=$logdir \
--output_dir=$output_midi \
--num_outputs=1 \
--num_steps=500 \
--hparams="batch_size=64,rnn_layer_sizes=[64,64]" \
--temperature=0.01 \
--primer_melody="[57, 56]"

#1--primer_melody="[53, 57, 62, 64]"
#2--primer_melody="[62, 60, 57, 56]"
#3--primer_melody="[57, 53, 55, 53]"
#4--primer_melody="[53, 62, 60, 57]"
#5--primer_melody="[64, 62, 56, 53]"
#6--primer_melody="[53, 57, 62, 53]"
#7--primer_melody="[62, 57, 56, 57]"
#8--primer_melody="[57, 56, 57, 53]"
#9--primer_melody="[64, 62]"
#10--primer_melody="[57, 56]"
# Out:
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# INFO:tensorflow:hparams = {'batch_size': 64, 'rnn_layer_sizes': [64, 64], 'dropout_keep_prob': 0.5, 'attn_length': 0, 'clip_norm': 5, 'learning_rate': 0.001, 'residual_connections': False, 'use_cudnn': False}
# I0622 08:34:16.795222  8088 events_rnn_graph.py:96] hparams = {'batch_size': 64, 'rnn_layer_sizes': [64, 64], 'dropout_keep_prob': 0.5, 'attn_length': 0, 'clip_norm': 5, 'learning_rate': 0.001, 'residual_connections': False, 'use_cudnn': False}
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:50: BasicLSTMCell.__init__ (from tensorflow.python.keras.layers.legacy_rnn.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0622 08:34:16.809185  8088 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:50: BasicLSTMCell.__init__ (from tensorflow.python.keras.layers.legacy_rnn.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:63: MultiRNNCell.__init__ (from tensorflow.python.keras.layers.legacy_rnn.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# W0622 08:34:16.826175  8088 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:63: MultiRNNCell.__init__ (from tensorflow.python.keras.layers.legacy_rnn.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:137: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# W0622 08:34:16.862205  8088 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:137: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:738: Layer.add_variable (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W0622 08:34:16.919593  8088 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:738: Layer.add_variable (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:744: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0622 08:34:16.929564  8088 deprecation.py:500] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:744: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tf_slim\layers\layers.py:1898: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0622 08:34:16.994911  8088 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\tf_slim\layers\layers.py:1898: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:253: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0622 08:34:17.012517  8088 deprecation.py:317] From c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\magenta\models\shared\events_rnn_graph.py:253: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# 2021-06-22 08:34:17.032345: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Checkpoint used: ./melody_rnn/logdir/run1\train\model.ckpt-40000
# I0622 08:34:17.036334  8088 model.py:57] Checkpoint used: ./melody_rnn/logdir/run1\train\model.ckpt-40000
# INFO:tensorflow:Restoring parameters from ./melody_rnn/logdir/run1\train\model.ckpt-40000
# I0622 08:34:17.039310  8088 saver.py:1293] Restoring parameters from ./melody_rnn/logdir/run1\train\model.ckpt-40000
# c:\users\jose.luis.tapia\anaconda3\envs\python38\lib\site-packages\note_seq\encoder_decoder.py:343: RuntimeWarning: divide by zero encountered in log
#   loglik += np.log(softmax[i][softmax_pos][index])
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -inf
# I0622 08:34:26.350851  8088 events_rnn_model.py:380] Beam search yields sequence with log-likelihood: -inf
# INFO:tensorflow:Wrote 1 MIDI files to ./melody_rnn/output_midi
# I0622 08:34:26.376776  8088 melody_rnn_generate.py:216] Wrote 1 MIDI files to ./melody_rnn/output_midi
